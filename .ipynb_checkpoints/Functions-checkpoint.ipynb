# %%
'''
- Function is used to make code reusable.
- Function is defined using def keyword.
- syntax
--------------
def function_name(arg1, arg2):
    logic...
    print(....)
    return ....
'''

# %%
'''
1. Argumented / Parameterized Functions
2. Non-Argumented / Non-Parameterized Functions
3. Return Type and Non-Return Type Functions
'''

# %%
def greet():
    print('Hello World!!')

# %%
greet()
# Out:
# 'Hello World!!'

# %%
def greet_name(name, age):
    print(f'Hello {name} {age}!!')

# %%
greet_name('Ram', 90)
# Out:
# 'Hello Ram 90!!'

# %%
def greet():
    return 'Hello World!!'

# %%
print(greet())
# Out:
# Hello World!!

# %%
def greet_name(name, age):
    return f'Hello {name} {age}!!'

# %%
greet_name('Ram', 90)
# Out:
# 'Hello Ram 90!!'

# %%
# append() -> data add
# value -> print, return

# %% [markdown]
# ## default argument and keyword argument

# %%
def employee_details(name, age=0, gender='M', jobPosition='Unknown Position', 
                     jobType='Unknown Type'):
    print(f'Name of Employee: {name}')
    print(f'Age of Employee: {age}')
    print(f'Gender of Employee: {gender}')
    print(f'Job Position of Employee: {jobPosition}')
    print(f'Job Type of Employee: {jobType}')

# %%
employee_details('Ram', 30, 'M')
# Out:
# Name of Employee: Ram
# Age of Employee: 30
# Gender of Employee: M
# Job Position of Employee: Unknown Position
# Job Type of Employee: Unknown Type

# %%
employee_details('Ram', 'M', jobType='Part-Time', jobPosition='Data Analyst')
# Out:
# Name of Employee: Ram
# Age of Employee: M
# Gender of Employee: M
# Job Position of Employee: Data Analyst
# Job Type of Employee: Part-Time

# %% [markdown]
# ## All Arguments (*args) and All Keyword Arguments (**kwargs)

# %%
def employeeDetails(*details):
    print(details)
    for data in details:
        print(data)

# %%
employeeDetails('Ram', 30, 'Kathmandu', 'Bachelors', 'Full-Time', 'Data Scientist')
# Out:
# ('Ram', 30, 'Kathmandu', 'Bachelors', 'Full-Time', 'Data Scientist')
# Ram
# 30
# Kathmandu
# Bachelors
# Full-Time
# Data Scientist

# %%
def employeeDetailsKwargs(**kwargs):
    print(kwargs)
    for key, val in kwargs.items():
        print(f'{key} of Employees: {val}')

# %%
employeeDetailsKwargs(Name='Ram', Age=30, JobType='Full-Time', JobPosition='Data Analyst')
# Out:
# {'Name': 'Ram', 'Age': 30, 'JobType': 'Full-Time', 'JobPosition': 'Data Analyst'}
# Name of Employees: Ram
# Age of Employees: 30
# JobType of Employees: Full-Time
# JobPosition of Employees: Data Analyst
